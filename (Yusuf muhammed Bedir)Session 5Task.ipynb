# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler , LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import plotly.express as px
import plotly.graph_objects as go

# %%
#Read CSV file
df=pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv" , index_col='customerID')

# %%
df
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
# ...            ...            ...     ...        ...     ...          ...
# 6840-RESVB    Male              0     Yes        Yes      24          Yes
# 2234-XADUH  Female              0     Yes        Yes      72          Yes
# 4801-JZAZL  Female              0     Yes        Yes      11           No
# 8361-LTMKD    Male              1     Yes         No       4          Yes
# 3186-AJIEK    Male              0      No         No      66          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
# ...                      ...             ...            ...          ...
# 6840-RESVB               Yes             DSL            Yes           No
# 2234-XADUH               Yes     Fiber optic             No          Yes
# 4801-JZAZL  No phone service             DSL            Yes           No
# 8361-LTMKD               Yes     Fiber optic             No           No
# 3186-AJIEK                No     Fiber optic            Yes           No
#
#            DeviceProtection TechSupport StreamingTV StreamingMovies  \
# customerID
# 7590-VHVEG               No          No          No              No
# 5575-GNVDE              Yes          No          No              No
# 3668-QPYBK               No          No          No              No
# 7795-CFOCW              Yes         Yes          No              No
# 9237-HQITU               No          No          No              No
# ...                     ...         ...         ...             ...
# 6840-RESVB              Yes         Yes         Yes             Yes
# 2234-XADUH              Yes          No         Yes             Yes
# 4801-JZAZL               No          No          No              No
# 8361-LTMKD               No          No          No              No
# 3186-AJIEK              Yes         Yes         Yes             Yes
#
#                   Contract PaperlessBilling              PaymentMethod  \
# customerID
# 7590-VHVEG  Month-to-month              Yes           Electronic check
# 5575-GNVDE        One year               No               Mailed check
# 3668-QPYBK  Month-to-month              Yes               Mailed check
# 7795-CFOCW        One year               No  Bank transfer (automatic)
# 9237-HQITU  Month-to-month              Yes           Electronic check
# ...                    ...              ...                        ...
# 6840-RESVB        One year              Yes               Mailed check
# 2234-XADUH        One year              Yes    Credit card (automatic)
# 4801-JZAZL  Month-to-month              Yes           Electronic check
# 8361-LTMKD  Month-to-month              Yes               Mailed check
# 3186-AJIEK        Two year              Yes  Bank transfer (automatic)
#
#             MonthlyCharges TotalCharges Churn
# customerID
# 7590-VHVEG           29.85        29.85    No
# 5575-GNVDE           56.95       1889.5    No
# 3668-QPYBK           53.85       108.15   Yes
# 7795-CFOCW           42.30      1840.75    No
# 9237-HQITU           70.70       151.65   Yes
# ...                    ...          ...   ...
# 6840-RESVB           84.80       1990.5    No
# 2234-XADUH          103.20       7362.9    No
# 4801-JZAZL           29.60       346.45    No
# 8361-LTMKD           74.40        306.6   Yes
# 3186-AJIEK          105.65       6844.5    No
#
# [7043 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7043 non-null   object
#  19  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
#Change Total charges to numeric 
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7032 non-null   float64
#  19  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 1.1+ MB

# %%
#Fill mising values of Total Charges with Avreage of total charges 
Charges_mean = df['TotalCharges'].mean()
df['TotalCharges'].fillna(Charges_mean, inplace=True)
# Out:
# C:\Users\bedir\AppData\Local\Temp\ipykernel_3760\4099157390.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TotalCharges'].fillna(Charges_mean, inplace=True)

# %%
df
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
# ...            ...            ...     ...        ...     ...          ...
# 6840-RESVB    Male              0     Yes        Yes      24          Yes
# 2234-XADUH  Female              0     Yes        Yes      72          Yes
# 4801-JZAZL  Female              0     Yes        Yes      11           No
# 8361-LTMKD    Male              1     Yes         No       4          Yes
# 3186-AJIEK    Male              0      No         No      66          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
# ...                      ...             ...            ...          ...
# 6840-RESVB               Yes             DSL            Yes           No
# 2234-XADUH               Yes     Fiber optic             No          Yes
# 4801-JZAZL  No phone service             DSL            Yes           No
# 8361-LTMKD               Yes     Fiber optic             No           No
# 3186-AJIEK                No     Fiber optic            Yes           No
#
#            DeviceProtection TechSupport StreamingTV StreamingMovies  \
# customerID
# 7590-VHVEG               No          No          No              No
# 5575-GNVDE              Yes          No          No              No
# 3668-QPYBK               No          No          No              No
# 7795-CFOCW              Yes         Yes          No              No
# 9237-HQITU               No          No          No              No
# ...                     ...         ...         ...             ...
# 6840-RESVB              Yes         Yes         Yes             Yes
# 2234-XADUH              Yes          No         Yes             Yes
# 4801-JZAZL               No          No          No              No
# 8361-LTMKD               No          No          No              No
# 3186-AJIEK              Yes         Yes         Yes             Yes
#
#                   Contract PaperlessBilling              PaymentMethod  \
# customerID
# 7590-VHVEG  Month-to-month              Yes           Electronic check
# 5575-GNVDE        One year               No               Mailed check
# 3668-QPYBK  Month-to-month              Yes               Mailed check
# 7795-CFOCW        One year               No  Bank transfer (automatic)
# 9237-HQITU  Month-to-month              Yes           Electronic check
# ...                    ...              ...                        ...
# 6840-RESVB        One year              Yes               Mailed check
# 2234-XADUH        One year              Yes    Credit card (automatic)
# 4801-JZAZL  Month-to-month              Yes           Electronic check
# 8361-LTMKD  Month-to-month              Yes               Mailed check
# 3186-AJIEK        Two year              Yes  Bank transfer (automatic)
#
#             MonthlyCharges  TotalCharges Churn
# customerID
# 7590-VHVEG           29.85         29.85    No
# 5575-GNVDE           56.95       1889.50    No
# 3668-QPYBK           53.85        108.15   Yes
# 7795-CFOCW           42.30       1840.75    No
# 9237-HQITU           70.70        151.65   Yes
# ...                    ...           ...   ...
# 6840-RESVB           84.80       1990.50    No
# 2234-XADUH          103.20       7362.90    No
# 4801-JZAZL           29.60        346.45    No
# 8361-LTMKD           74.40        306.60   Yes
# 3186-AJIEK          105.65       6844.50    No
#
# [7043 rows x 20 columns]

# %%
#Specify dtype = object columns to one hot encode
df.select_dtypes('object').columns
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %%
df_encoded = pd.get_dummies(df, columns = ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
       'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies',
       'PaperlessBilling', 'PaymentMethod'])
df_encoded
# Out:
#             SeniorCitizen  tenure        Contract  MonthlyCharges  \
# customerID
# 7590-VHVEG              0       1  Month-to-month           29.85
# 5575-GNVDE              0      34        One year           56.95
# 3668-QPYBK              0       2  Month-to-month           53.85
# 7795-CFOCW              0      45        One year           42.30
# 9237-HQITU              0       2  Month-to-month           70.70
# ...                   ...     ...             ...             ...
# 6840-RESVB              0      24        One year           84.80
# 2234-XADUH              0      72        One year          103.20
# 4801-JZAZL              0      11  Month-to-month           29.60
# 8361-LTMKD              1       4  Month-to-month           74.40
# 3186-AJIEK              0      66        Two year          105.65
#
#             TotalCharges Churn  gender_Female  gender_Male  Partner_No  \
# customerID
# 7590-VHVEG         29.85    No           True        False       False
# 5575-GNVDE       1889.50    No          False         True        True
# 3668-QPYBK        108.15   Yes          False         True        True
# 7795-CFOCW       1840.75    No          False         True        True
# 9237-HQITU        151.65   Yes           True        False        True
# ...                  ...   ...            ...          ...         ...
# 6840-RESVB       1990.50    No          False         True       False
# 2234-XADUH       7362.90    No           True        False       False
# 4801-JZAZL        346.45    No           True        False       False
# 8361-LTMKD        306.60   Yes          False         True       False
# 3186-AJIEK       6844.50    No          False         True        True
#
#             Partner_Yes  ...  StreamingTV_Yes  StreamingMovies_No  \
# customerID               ...
# 7590-VHVEG         True  ...            False                True
# 5575-GNVDE        False  ...            False                True
# 3668-QPYBK        False  ...            False                True
# 7795-CFOCW        False  ...            False                True
# 9237-HQITU        False  ...            False                True
# ...                 ...  ...              ...                 ...
# 6840-RESVB         True  ...             True               False
# 2234-XADUH         True  ...             True               False
# 4801-JZAZL         True  ...            False                True
# 8361-LTMKD         True  ...            False                True
# 3186-AJIEK        False  ...             True               False
#
#             StreamingMovies_No internet service  StreamingMovies_Yes  \
# customerID
# 7590-VHVEG                                False                False
# 5575-GNVDE                                False                False
# 3668-QPYBK                                False                False
# 7795-CFOCW                                False                False
# 9237-HQITU                                False                False
# ...                                         ...                  ...
# 6840-RESVB                                False                 True
# 2234-XADUH                                False                 True
# 4801-JZAZL                                False                False
# 8361-LTMKD                                False                False
# 3186-AJIEK                                False                 True
#
#             PaperlessBilling_No  PaperlessBilling_Yes  \
# customerID
# 7590-VHVEG                False                  True
# 5575-GNVDE                 True                 False
# 3668-QPYBK                False                  True
# 7795-CFOCW                 True                 False
# 9237-HQITU                False                  True
# ...                         ...                   ...
# 6840-RESVB                False                  True
# 2234-XADUH                False                  True
# 4801-JZAZL                False                  True
# 8361-LTMKD                False                  True
# 3186-AJIEK                False                  True
#
#             PaymentMethod_Bank transfer (automatic)  \
# customerID
# 7590-VHVEG                                    False
# 5575-GNVDE                                    False
# 3668-QPYBK                                    False
# 7795-CFOCW                                     True
# 9237-HQITU                                    False
# ...                                             ...
# 6840-RESVB                                    False
# 2234-XADUH                                    False
# 4801-JZAZL                                    False
# 8361-LTMKD                                    False
# 3186-AJIEK                                     True
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 7590-VHVEG                                  False
# 5575-GNVDE                                  False
# 3668-QPYBK                                  False
# 7795-CFOCW                                  False
# 9237-HQITU                                  False
# ...                                           ...
# 6840-RESVB                                  False
# 2234-XADUH                                   True
# 4801-JZAZL                                  False
# 8361-LTMKD                                  False
# 3186-AJIEK                                  False
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check
# customerID
# 7590-VHVEG                            True                       False
# 5575-GNVDE                           False                        True
# 3668-QPYBK                           False                        True
# 7795-CFOCW                           False                       False
# 9237-HQITU                            True                       False
# ...                                    ...                         ...
# 6840-RESVB                           False                        True
# 2234-XADUH                           False                       False
# 4801-JZAZL                            True                       False
# 8361-LTMKD                           False                        True
# 3186-AJIEK                           False                       False
#
# [7043 rows x 44 columns]

# %%
replaced = {"Month-to-month": "1" , "One year": "2" , "Two year": "3"}

# %%
df_encoded['Contract'] = df_encoded['Contract'].replace(replaced)

# %%
df_encoded
# Out:
#             SeniorCitizen  tenure Contract  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG              0       1        1           29.85         29.85
# 5575-GNVDE              0      34        2           56.95       1889.50
# 3668-QPYBK              0       2        1           53.85        108.15
# 7795-CFOCW              0      45        2           42.30       1840.75
# 9237-HQITU              0       2        1           70.70        151.65
# ...                   ...     ...      ...             ...           ...
# 6840-RESVB              0      24        2           84.80       1990.50
# 2234-XADUH              0      72        2          103.20       7362.90
# 4801-JZAZL              0      11        1           29.60        346.45
# 8361-LTMKD              1       4        1           74.40        306.60
# 3186-AJIEK              0      66        3          105.65       6844.50
#
#            Churn  gender_Female  gender_Male  Partner_No  Partner_Yes  ...  \
# customerID                                                             ...
# 7590-VHVEG    No           True        False       False         True  ...
# 5575-GNVDE    No          False         True        True        False  ...
# 3668-QPYBK   Yes          False         True        True        False  ...
# 7795-CFOCW    No          False         True        True        False  ...
# 9237-HQITU   Yes           True        False        True        False  ...
# ...          ...            ...          ...         ...          ...  ...
# 6840-RESVB    No          False         True       False         True  ...
# 2234-XADUH    No           True        False       False         True  ...
# 4801-JZAZL    No           True        False       False         True  ...
# 8361-LTMKD   Yes          False         True       False         True  ...
# 3186-AJIEK    No          False         True        True        False  ...
#
#             StreamingTV_Yes  StreamingMovies_No  \
# customerID
# 7590-VHVEG            False                True
# 5575-GNVDE            False                True
# 3668-QPYBK            False                True
# 7795-CFOCW            False                True
# 9237-HQITU            False                True
# ...                     ...                 ...
# 6840-RESVB             True               False
# 2234-XADUH             True               False
# 4801-JZAZL            False                True
# 8361-LTMKD            False                True
# 3186-AJIEK             True               False
#
#             StreamingMovies_No internet service  StreamingMovies_Yes  \
# customerID
# 7590-VHVEG                                False                False
# 5575-GNVDE                                False                False
# 3668-QPYBK                                False                False
# 7795-CFOCW                                False                False
# 9237-HQITU                                False                False
# ...                                         ...                  ...
# 6840-RESVB                                False                 True
# 2234-XADUH                                False                 True
# 4801-JZAZL                                False                False
# 8361-LTMKD                                False                False
# 3186-AJIEK                                False                 True
#
#             PaperlessBilling_No  PaperlessBilling_Yes  \
# customerID
# 7590-VHVEG                False                  True
# 5575-GNVDE                 True                 False
# 3668-QPYBK                False                  True
# 7795-CFOCW                 True                 False
# 9237-HQITU                False                  True
# ...                         ...                   ...
# 6840-RESVB                False                  True
# 2234-XADUH                False                  True
# 4801-JZAZL                False                  True
# 8361-LTMKD                False                  True
# 3186-AJIEK                False                  True
#
#             PaymentMethod_Bank transfer (automatic)  \
# customerID
# 7590-VHVEG                                    False
# 5575-GNVDE                                    False
# 3668-QPYBK                                    False
# 7795-CFOCW                                     True
# 9237-HQITU                                    False
# ...                                             ...
# 6840-RESVB                                    False
# 2234-XADUH                                    False
# 4801-JZAZL                                    False
# 8361-LTMKD                                    False
# 3186-AJIEK                                     True
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 7590-VHVEG                                  False
# 5575-GNVDE                                  False
# 3668-QPYBK                                  False
# 7795-CFOCW                                  False
# 9237-HQITU                                  False
# ...                                           ...
# 6840-RESVB                                  False
# 2234-XADUH                                   True
# 4801-JZAZL                                  False
# 8361-LTMKD                                  False
# 3186-AJIEK                                  False
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check
# customerID
# 7590-VHVEG                            True                       False
# 5575-GNVDE                           False                        True
# 3668-QPYBK                           False                        True
# 7795-CFOCW                           False                       False
# 9237-HQITU                            True                       False
# ...                                    ...                         ...
# 6840-RESVB                           False                        True
# 2234-XADUH                           False                       False
# 4801-JZAZL                            True                       False
# 8361-LTMKD                           False                        True
# 3186-AJIEK                           False                       False
#
# [7043 rows x 44 columns]

# %%
df_encoded['Contract'] = pd.to_numeric(df_encoded['Contract'])

# %%
df_encoded
# Out:
#             SeniorCitizen  tenure  Contract  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG              0       1         1           29.85         29.85
# 5575-GNVDE              0      34         2           56.95       1889.50
# 3668-QPYBK              0       2         1           53.85        108.15
# 7795-CFOCW              0      45         2           42.30       1840.75
# 9237-HQITU              0       2         1           70.70        151.65
# ...                   ...     ...       ...             ...           ...
# 6840-RESVB              0      24         2           84.80       1990.50
# 2234-XADUH              0      72         2          103.20       7362.90
# 4801-JZAZL              0      11         1           29.60        346.45
# 8361-LTMKD              1       4         1           74.40        306.60
# 3186-AJIEK              0      66         3          105.65       6844.50
#
#            Churn  gender_Female  gender_Male  Partner_No  Partner_Yes  ...  \
# customerID                                                             ...
# 7590-VHVEG    No           True        False       False         True  ...
# 5575-GNVDE    No          False         True        True        False  ...
# 3668-QPYBK   Yes          False         True        True        False  ...
# 7795-CFOCW    No          False         True        True        False  ...
# 9237-HQITU   Yes           True        False        True        False  ...
# ...          ...            ...          ...         ...          ...  ...
# 6840-RESVB    No          False         True       False         True  ...
# 2234-XADUH    No           True        False       False         True  ...
# 4801-JZAZL    No           True        False       False         True  ...
# 8361-LTMKD   Yes          False         True       False         True  ...
# 3186-AJIEK    No          False         True        True        False  ...
#
#             StreamingTV_Yes  StreamingMovies_No  \
# customerID
# 7590-VHVEG            False                True
# 5575-GNVDE            False                True
# 3668-QPYBK            False                True
# 7795-CFOCW            False                True
# 9237-HQITU            False                True
# ...                     ...                 ...
# 6840-RESVB             True               False
# 2234-XADUH             True               False
# 4801-JZAZL            False                True
# 8361-LTMKD            False                True
# 3186-AJIEK             True               False
#
#             StreamingMovies_No internet service  StreamingMovies_Yes  \
# customerID
# 7590-VHVEG                                False                False
# 5575-GNVDE                                False                False
# 3668-QPYBK                                False                False
# 7795-CFOCW                                False                False
# 9237-HQITU                                False                False
# ...                                         ...                  ...
# 6840-RESVB                                False                 True
# 2234-XADUH                                False                 True
# 4801-JZAZL                                False                False
# 8361-LTMKD                                False                False
# 3186-AJIEK                                False                 True
#
#             PaperlessBilling_No  PaperlessBilling_Yes  \
# customerID
# 7590-VHVEG                False                  True
# 5575-GNVDE                 True                 False
# 3668-QPYBK                False                  True
# 7795-CFOCW                 True                 False
# 9237-HQITU                False                  True
# ...                         ...                   ...
# 6840-RESVB                False                  True
# 2234-XADUH                False                  True
# 4801-JZAZL                False                  True
# 8361-LTMKD                False                  True
# 3186-AJIEK                False                  True
#
#             PaymentMethod_Bank transfer (automatic)  \
# customerID
# 7590-VHVEG                                    False
# 5575-GNVDE                                    False
# 3668-QPYBK                                    False
# 7795-CFOCW                                     True
# 9237-HQITU                                    False
# ...                                             ...
# 6840-RESVB                                    False
# 2234-XADUH                                    False
# 4801-JZAZL                                    False
# 8361-LTMKD                                    False
# 3186-AJIEK                                     True
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 7590-VHVEG                                  False
# 5575-GNVDE                                  False
# 3668-QPYBK                                  False
# 7795-CFOCW                                  False
# 9237-HQITU                                  False
# ...                                           ...
# 6840-RESVB                                  False
# 2234-XADUH                                   True
# 4801-JZAZL                                  False
# 8361-LTMKD                                  False
# 3186-AJIEK                                  False
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check
# customerID
# 7590-VHVEG                            True                       False
# 5575-GNVDE                           False                        True
# 3668-QPYBK                           False                        True
# 7795-CFOCW                           False                       False
# 9237-HQITU                            True                       False
# ...                                    ...                         ...
# 6840-RESVB                           False                        True
# 2234-XADUH                           False                       False
# 4801-JZAZL                            True                       False
# 8361-LTMKD                           False                        True
# 3186-AJIEK                           False                       False
#
# [7043 rows x 44 columns]

# %%
df_encoded=df_encoded.drop_duplicates()

# %%
df_encoded
# Out:
#             SeniorCitizen  tenure  Contract  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG              0       1         1           29.85         29.85
# 5575-GNVDE              0      34         2           56.95       1889.50
# 3668-QPYBK              0       2         1           53.85        108.15
# 7795-CFOCW              0      45         2           42.30       1840.75
# 9237-HQITU              0       2         1           70.70        151.65
# ...                   ...     ...       ...             ...           ...
# 6840-RESVB              0      24         2           84.80       1990.50
# 2234-XADUH              0      72         2          103.20       7362.90
# 4801-JZAZL              0      11         1           29.60        346.45
# 8361-LTMKD              1       4         1           74.40        306.60
# 3186-AJIEK              0      66         3          105.65       6844.50
#
#            Churn  gender_Female  gender_Male  Partner_No  Partner_Yes  ...  \
# customerID                                                             ...
# 7590-VHVEG    No           True        False       False         True  ...
# 5575-GNVDE    No          False         True        True        False  ...
# 3668-QPYBK   Yes          False         True        True        False  ...
# 7795-CFOCW    No          False         True        True        False  ...
# 9237-HQITU   Yes           True        False        True        False  ...
# ...          ...            ...          ...         ...          ...  ...
# 6840-RESVB    No          False         True       False         True  ...
# 2234-XADUH    No           True        False       False         True  ...
# 4801-JZAZL    No           True        False       False         True  ...
# 8361-LTMKD   Yes          False         True       False         True  ...
# 3186-AJIEK    No          False         True        True        False  ...
#
#             StreamingTV_Yes  StreamingMovies_No  \
# customerID
# 7590-VHVEG            False                True
# 5575-GNVDE            False                True
# 3668-QPYBK            False                True
# 7795-CFOCW            False                True
# 9237-HQITU            False                True
# ...                     ...                 ...
# 6840-RESVB             True               False
# 2234-XADUH             True               False
# 4801-JZAZL            False                True
# 8361-LTMKD            False                True
# 3186-AJIEK             True               False
#
#             StreamingMovies_No internet service  StreamingMovies_Yes  \
# customerID
# 7590-VHVEG                                False                False
# 5575-GNVDE                                False                False
# 3668-QPYBK                                False                False
# 7795-CFOCW                                False                False
# 9237-HQITU                                False                False
# ...                                         ...                  ...
# 6840-RESVB                                False                 True
# 2234-XADUH                                False                 True
# 4801-JZAZL                                False                False
# 8361-LTMKD                                False                False
# 3186-AJIEK                                False                 True
#
#             PaperlessBilling_No  PaperlessBilling_Yes  \
# customerID
# 7590-VHVEG                False                  True
# 5575-GNVDE                 True                 False
# 3668-QPYBK                False                  True
# 7795-CFOCW                 True                 False
# 9237-HQITU                False                  True
# ...                         ...                   ...
# 6840-RESVB                False                  True
# 2234-XADUH                False                  True
# 4801-JZAZL                False                  True
# 8361-LTMKD                False                  True
# 3186-AJIEK                False                  True
#
#             PaymentMethod_Bank transfer (automatic)  \
# customerID
# 7590-VHVEG                                    False
# 5575-GNVDE                                    False
# 3668-QPYBK                                    False
# 7795-CFOCW                                     True
# 9237-HQITU                                    False
# ...                                             ...
# 6840-RESVB                                    False
# 2234-XADUH                                    False
# 4801-JZAZL                                    False
# 8361-LTMKD                                    False
# 3186-AJIEK                                     True
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 7590-VHVEG                                  False
# 5575-GNVDE                                  False
# 3668-QPYBK                                  False
# 7795-CFOCW                                  False
# 9237-HQITU                                  False
# ...                                           ...
# 6840-RESVB                                  False
# 2234-XADUH                                   True
# 4801-JZAZL                                  False
# 8361-LTMKD                                  False
# 3186-AJIEK                                  False
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check
# customerID
# 7590-VHVEG                            True                       False
# 5575-GNVDE                           False                        True
# 3668-QPYBK                           False                        True
# 7795-CFOCW                           False                       False
# 9237-HQITU                            True                       False
# ...                                    ...                         ...
# 6840-RESVB                           False                        True
# 2234-XADUH                           False                       False
# 4801-JZAZL                            True                       False
# 8361-LTMKD                           False                        True
# 3186-AJIEK                           False                       False
#
# [7021 rows x 44 columns]

# %%
label_encoder = LabelEncoder()
df_encoded['Churn'] = label_encoder.fit_transform(df_encoded['Churn'])
# Out:
# C:\Users\bedir\AppData\Local\Temp\ipykernel_3760\2869873551.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded['Churn'] = label_encoder.fit_transform(df_encoded['Churn'])

# %%
df_encoded
# Out:
#             SeniorCitizen  tenure  Contract  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG              0       1         1           29.85         29.85
# 5575-GNVDE              0      34         2           56.95       1889.50
# 3668-QPYBK              0       2         1           53.85        108.15
# 7795-CFOCW              0      45         2           42.30       1840.75
# 9237-HQITU              0       2         1           70.70        151.65
# ...                   ...     ...       ...             ...           ...
# 6840-RESVB              0      24         2           84.80       1990.50
# 2234-XADUH              0      72         2          103.20       7362.90
# 4801-JZAZL              0      11         1           29.60        346.45
# 8361-LTMKD              1       4         1           74.40        306.60
# 3186-AJIEK              0      66         3          105.65       6844.50
#
#             Churn  gender_Female  gender_Male  Partner_No  Partner_Yes  ...  \
# customerID                                                              ...
# 7590-VHVEG      0           True        False       False         True  ...
# 5575-GNVDE      0          False         True        True        False  ...
# 3668-QPYBK      1          False         True        True        False  ...
# 7795-CFOCW      0          False         True        True        False  ...
# 9237-HQITU      1           True        False        True        False  ...
# ...           ...            ...          ...         ...          ...  ...
# 6840-RESVB      0          False         True       False         True  ...
# 2234-XADUH      0           True        False       False         True  ...
# 4801-JZAZL      0           True        False       False         True  ...
# 8361-LTMKD      1          False         True       False         True  ...
# 3186-AJIEK      0          False         True        True        False  ...
#
#             StreamingTV_Yes  StreamingMovies_No  \
# customerID
# 7590-VHVEG            False                True
# 5575-GNVDE            False                True
# 3668-QPYBK            False                True
# 7795-CFOCW            False                True
# 9237-HQITU            False                True
# ...                     ...                 ...
# 6840-RESVB             True               False
# 2234-XADUH             True               False
# 4801-JZAZL            False                True
# 8361-LTMKD            False                True
# 3186-AJIEK             True               False
#
#             StreamingMovies_No internet service  StreamingMovies_Yes  \
# customerID
# 7590-VHVEG                                False                False
# 5575-GNVDE                                False                False
# 3668-QPYBK                                False                False
# 7795-CFOCW                                False                False
# 9237-HQITU                                False                False
# ...                                         ...                  ...
# 6840-RESVB                                False                 True
# 2234-XADUH                                False                 True
# 4801-JZAZL                                False                False
# 8361-LTMKD                                False                False
# 3186-AJIEK                                False                 True
#
#             PaperlessBilling_No  PaperlessBilling_Yes  \
# customerID
# 7590-VHVEG                False                  True
# 5575-GNVDE                 True                 False
# 3668-QPYBK                False                  True
# 7795-CFOCW                 True                 False
# 9237-HQITU                False                  True
# ...                         ...                   ...
# 6840-RESVB                False                  True
# 2234-XADUH                False                  True
# 4801-JZAZL                False                  True
# 8361-LTMKD                False                  True
# 3186-AJIEK                False                  True
#
#             PaymentMethod_Bank transfer (automatic)  \
# customerID
# 7590-VHVEG                                    False
# 5575-GNVDE                                    False
# 3668-QPYBK                                    False
# 7795-CFOCW                                     True
# 9237-HQITU                                    False
# ...                                             ...
# 6840-RESVB                                    False
# 2234-XADUH                                    False
# 4801-JZAZL                                    False
# 8361-LTMKD                                    False
# 3186-AJIEK                                     True
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 7590-VHVEG                                  False
# 5575-GNVDE                                  False
# 3668-QPYBK                                  False
# 7795-CFOCW                                  False
# 9237-HQITU                                  False
# ...                                           ...
# 6840-RESVB                                  False
# 2234-XADUH                                   True
# 4801-JZAZL                                  False
# 8361-LTMKD                                  False
# 3186-AJIEK                                  False
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check
# customerID
# 7590-VHVEG                            True                       False
# 5575-GNVDE                           False                        True
# 3668-QPYBK                           False                        True
# 7795-CFOCW                           False                       False
# 9237-HQITU                            True                       False
# ...                                    ...                         ...
# 6840-RESVB                           False                        True
# 2234-XADUH                           False                       False
# 4801-JZAZL                            True                       False
# 8361-LTMKD                           False                        True
# 3186-AJIEK                           False                       False
#
# [7021 rows x 44 columns]

# %%
df_encoded['Churn'] = pd.to_numeric(df_encoded['Churn'], errors='coerce')
# Out:
# C:\Users\bedir\AppData\Local\Temp\ipykernel_3760\3054950313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded['Churn'] = pd.to_numeric(df_encoded['Churn'], errors='coerce')

# %%
df_encoded
# Out:
#             SeniorCitizen  tenure  Contract  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG              0       1         1           29.85         29.85
# 5575-GNVDE              0      34         2           56.95       1889.50
# 3668-QPYBK              0       2         1           53.85        108.15
# 7795-CFOCW              0      45         2           42.30       1840.75
# 9237-HQITU              0       2         1           70.70        151.65
# ...                   ...     ...       ...             ...           ...
# 6840-RESVB              0      24         2           84.80       1990.50
# 2234-XADUH              0      72         2          103.20       7362.90
# 4801-JZAZL              0      11         1           29.60        346.45
# 8361-LTMKD              1       4         1           74.40        306.60
# 3186-AJIEK              0      66         3          105.65       6844.50
#
#             Churn  gender_Female  gender_Male  Partner_No  Partner_Yes  ...  \
# customerID                                                              ...
# 7590-VHVEG      0           True        False       False         True  ...
# 5575-GNVDE      0          False         True        True        False  ...
# 3668-QPYBK      1          False         True        True        False  ...
# 7795-CFOCW      0          False         True        True        False  ...
# 9237-HQITU      1           True        False        True        False  ...
# ...           ...            ...          ...         ...          ...  ...
# 6840-RESVB      0          False         True       False         True  ...
# 2234-XADUH      0           True        False       False         True  ...
# 4801-JZAZL      0           True        False       False         True  ...
# 8361-LTMKD      1          False         True       False         True  ...
# 3186-AJIEK      0          False         True        True        False  ...
#
#             StreamingTV_Yes  StreamingMovies_No  \
# customerID
# 7590-VHVEG            False                True
# 5575-GNVDE            False                True
# 3668-QPYBK            False                True
# 7795-CFOCW            False                True
# 9237-HQITU            False                True
# ...                     ...                 ...
# 6840-RESVB             True               False
# 2234-XADUH             True               False
# 4801-JZAZL            False                True
# 8361-LTMKD            False                True
# 3186-AJIEK             True               False
#
#             StreamingMovies_No internet service  StreamingMovies_Yes  \
# customerID
# 7590-VHVEG                                False                False
# 5575-GNVDE                                False                False
# 3668-QPYBK                                False                False
# 7795-CFOCW                                False                False
# 9237-HQITU                                False                False
# ...                                         ...                  ...
# 6840-RESVB                                False                 True
# 2234-XADUH                                False                 True
# 4801-JZAZL                                False                False
# 8361-LTMKD                                False                False
# 3186-AJIEK                                False                 True
#
#             PaperlessBilling_No  PaperlessBilling_Yes  \
# customerID
# 7590-VHVEG                False                  True
# 5575-GNVDE                 True                 False
# 3668-QPYBK                False                  True
# 7795-CFOCW                 True                 False
# 9237-HQITU                False                  True
# ...                         ...                   ...
# 6840-RESVB                False                  True
# 2234-XADUH                False                  True
# 4801-JZAZL                False                  True
# 8361-LTMKD                False                  True
# 3186-AJIEK                False                  True
#
#             PaymentMethod_Bank transfer (automatic)  \
# customerID
# 7590-VHVEG                                    False
# 5575-GNVDE                                    False
# 3668-QPYBK                                    False
# 7795-CFOCW                                     True
# 9237-HQITU                                    False
# ...                                             ...
# 6840-RESVB                                    False
# 2234-XADUH                                    False
# 4801-JZAZL                                    False
# 8361-LTMKD                                    False
# 3186-AJIEK                                     True
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 7590-VHVEG                                  False
# 5575-GNVDE                                  False
# 3668-QPYBK                                  False
# 7795-CFOCW                                  False
# 9237-HQITU                                  False
# ...                                           ...
# 6840-RESVB                                  False
# 2234-XADUH                                   True
# 4801-JZAZL                                  False
# 8361-LTMKD                                  False
# 3186-AJIEK                                  False
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check
# customerID
# 7590-VHVEG                            True                       False
# 5575-GNVDE                           False                        True
# 3668-QPYBK                           False                        True
# 7795-CFOCW                           False                       False
# 9237-HQITU                            True                       False
# ...                                    ...                         ...
# 6840-RESVB                           False                        True
# 2234-XADUH                           False                       False
# 4801-JZAZL                            True                       False
# 8361-LTMKD                           False                        True
# 3186-AJIEK                           False                       False
#
# [7021 rows x 44 columns]

# %%
df_churn = df_encoded[['Churn']]

# %%
df_churn
# Out:
#             Churn
# customerID
# 7590-VHVEG      0
# 5575-GNVDE      0
# 3668-QPYBK      1
# 7795-CFOCW      0
# 9237-HQITU      1
# ...           ...
# 6840-RESVB      0
# 2234-XADUH      0
# 4801-JZAZL      0
# 8361-LTMKD      1
# 3186-AJIEK      0
#
# [7021 rows x 1 columns]

# %%
df_encoded = df_encoded.drop('Churn' , axis=1)

# %%
df_encoded
# Out:
#             SeniorCitizen  tenure  Contract  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG              0       1         1           29.85         29.85
# 5575-GNVDE              0      34         2           56.95       1889.50
# 3668-QPYBK              0       2         1           53.85        108.15
# 7795-CFOCW              0      45         2           42.30       1840.75
# 9237-HQITU              0       2         1           70.70        151.65
# ...                   ...     ...       ...             ...           ...
# 6840-RESVB              0      24         2           84.80       1990.50
# 2234-XADUH              0      72         2          103.20       7362.90
# 4801-JZAZL              0      11         1           29.60        346.45
# 8361-LTMKD              1       4         1           74.40        306.60
# 3186-AJIEK              0      66         3          105.65       6844.50
#
#             gender_Female  gender_Male  Partner_No  Partner_Yes  \
# customerID
# 7590-VHVEG           True        False       False         True
# 5575-GNVDE          False         True        True        False
# 3668-QPYBK          False         True        True        False
# 7795-CFOCW          False         True        True        False
# 9237-HQITU           True        False        True        False
# ...                   ...          ...         ...          ...
# 6840-RESVB          False         True       False         True
# 2234-XADUH           True        False       False         True
# 4801-JZAZL           True        False       False         True
# 8361-LTMKD          False         True       False         True
# 3186-AJIEK          False         True        True        False
#
#             Dependents_No  ...  StreamingTV_Yes  StreamingMovies_No  \
# customerID                 ...
# 7590-VHVEG           True  ...            False                True
# 5575-GNVDE           True  ...            False                True
# 3668-QPYBK           True  ...            False                True
# 7795-CFOCW           True  ...            False                True
# 9237-HQITU           True  ...            False                True
# ...                   ...  ...              ...                 ...
# 6840-RESVB          False  ...             True               False
# 2234-XADUH          False  ...             True               False
# 4801-JZAZL          False  ...            False                True
# 8361-LTMKD           True  ...            False                True
# 3186-AJIEK           True  ...             True               False
#
#             StreamingMovies_No internet service  StreamingMovies_Yes  \
# customerID
# 7590-VHVEG                                False                False
# 5575-GNVDE                                False                False
# 3668-QPYBK                                False                False
# 7795-CFOCW                                False                False
# 9237-HQITU                                False                False
# ...                                         ...                  ...
# 6840-RESVB                                False                 True
# 2234-XADUH                                False                 True
# 4801-JZAZL                                False                False
# 8361-LTMKD                                False                False
# 3186-AJIEK                                False                 True
#
#             PaperlessBilling_No  PaperlessBilling_Yes  \
# customerID
# 7590-VHVEG                False                  True
# 5575-GNVDE                 True                 False
# 3668-QPYBK                False                  True
# 7795-CFOCW                 True                 False
# 9237-HQITU                False                  True
# ...                         ...                   ...
# 6840-RESVB                False                  True
# 2234-XADUH                False                  True
# 4801-JZAZL                False                  True
# 8361-LTMKD                False                  True
# 3186-AJIEK                False                  True
#
#             PaymentMethod_Bank transfer (automatic)  \
# customerID
# 7590-VHVEG                                    False
# 5575-GNVDE                                    False
# 3668-QPYBK                                    False
# 7795-CFOCW                                     True
# 9237-HQITU                                    False
# ...                                             ...
# 6840-RESVB                                    False
# 2234-XADUH                                    False
# 4801-JZAZL                                    False
# 8361-LTMKD                                    False
# 3186-AJIEK                                     True
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 7590-VHVEG                                  False
# 5575-GNVDE                                  False
# 3668-QPYBK                                  False
# 7795-CFOCW                                  False
# 9237-HQITU                                  False
# ...                                           ...
# 6840-RESVB                                  False
# 2234-XADUH                                   True
# 4801-JZAZL                                  False
# 8361-LTMKD                                  False
# 3186-AJIEK                                  False
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check
# customerID
# 7590-VHVEG                            True                       False
# 5575-GNVDE                           False                        True
# 3668-QPYBK                           False                        True
# 7795-CFOCW                           False                       False
# 9237-HQITU                            True                       False
# ...                                    ...                         ...
# 6840-RESVB                           False                        True
# 2234-XADUH                           False                       False
# 4801-JZAZL                            True                       False
# 8361-LTMKD                           False                        True
# 3186-AJIEK                           False                       False
#
# [7021 rows x 43 columns]

# %%
df_encoded.select_dtypes('number').columns
# Out:
# Index(['SeniorCitizen', 'tenure', 'Contract', 'MonthlyCharges',
#        'TotalCharges'],
#       dtype='object')

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7021 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 43 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   SeniorCitizen                            7021 non-null   int64
#  1   tenure                                   7021 non-null   int64
#  2   Contract                                 7021 non-null   int64
#  3   MonthlyCharges                           7021 non-null   float64
#  4   TotalCharges                             7021 non-null   float64
#  5   gender_Female                            7021 non-null   bool
#  6   gender_Male                              7021 non-null   bool
#  7   Partner_No                               7021 non-null   bool
#  8   Partner_Yes                              7021 non-null   bool
#  9   Dependents_No                            7021 non-null   bool
#  10  Dependents_Yes                           7021 non-null   bool
#  11  PhoneService_No                          7021 non-null   bool
#  12  PhoneService_Yes                         7021 non-null   bool
#  13  MultipleLines_No                         7021 non-null   bool
#  14  MultipleLines_No phone service           7021 non-null   bool
#  15  MultipleLines_Yes                        7021 non-null   bool
#  16  InternetService_DSL                      7021 non-null   bool
#  17  InternetService_Fiber optic              7021 non-null   bool
#  18  InternetService_No                       7021 non-null   bool
#  19  OnlineSecurity_No                        7021 non-null   bool
#  20  OnlineSecurity_No internet service       7021 non-null   bool
#  21  OnlineSecurity_Yes                       7021 non-null   bool
#  22  OnlineBackup_No                          7021 non-null   bool
#  23  OnlineBackup_No internet service         7021 non-null   bool
#  24  OnlineBackup_Yes                         7021 non-null   bool
#  25  DeviceProtection_No                      7021 non-null   bool
#  26  DeviceProtection_No internet service     7021 non-null   bool
#  27  DeviceProtection_Yes                     7021 non-null   bool
#  28  TechSupport_No                           7021 non-null   bool
#  29  TechSupport_No internet service          7021 non-null   bool
#  30  TechSupport_Yes                          7021 non-null   bool
#  31  StreamingTV_No                           7021 non-null   bool
#  32  StreamingTV_No internet service          7021 non-null   bool
#  33  StreamingTV_Yes                          7021 non-null   bool
#  34  StreamingMovies_No                       7021 non-null   bool
#  35  StreamingMovies_No internet service      7021 non-null   bool
#  36  StreamingMovies_Yes                      7021 non-null   bool
#  37  PaperlessBilling_No                      7021 non-null   bool
#  38  PaperlessBilling_Yes                     7021 non-null   bool
#  39  PaymentMethod_Bank transfer (automatic)  7021 non-null   bool
#  40  PaymentMethod_Credit card (automatic)    7021 non-null   bool
#  41  PaymentMethod_Electronic check           7021 non-null   bool
#  42  PaymentMethod_Mailed check               7021 non-null   bool
# dtypes: bool(38), float64(2), int64(3)
# memory usage: 847.7+ KB

# %%
# Identify numerical columns
numerical_cols = df_encoded.select_dtypes(include=['int64', 'float64']).columns

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Normalize only the numerical columns
df_encoded[numerical_cols] = scaler.fit_transform(df_encoded[numerical_cols])

# Display the updated DataFrame
df_encoded
# Out:
#             SeniorCitizen    tenure  Contract  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG            0.0  0.013889       0.0        0.115423      0.001275
# 5575-GNVDE            0.0  0.472222       0.5        0.385075      0.215867
# 3668-QPYBK            0.0  0.027778       0.0        0.354229      0.010310
# 7795-CFOCW            0.0  0.625000       0.5        0.239303      0.210241
# 9237-HQITU            0.0  0.027778       0.0        0.521891      0.015330
# ...                   ...       ...       ...             ...           ...
# 6840-RESVB            0.0  0.333333       0.5        0.662189      0.227521
# 2234-XADUH            0.0  1.000000       0.5        0.845274      0.847461
# 4801-JZAZL            0.0  0.152778       0.0        0.112935      0.037809
# 8361-LTMKD            1.0  0.055556       0.0        0.558706      0.033210
# 3186-AJIEK            0.0  0.916667       1.0        0.869652      0.787641
#
#             gender_Female  gender_Male  Partner_No  Partner_Yes  \
# customerID
# 7590-VHVEG           True        False       False         True
# 5575-GNVDE          False         True        True        False
# 3668-QPYBK          False         True        True        False
# 7795-CFOCW          False         True        True        False
# 9237-HQITU           True        False        True        False
# ...                   ...          ...         ...          ...
# 6840-RESVB          False         True       False         True
# 2234-XADUH           True        False       False         True
# 4801-JZAZL           True        False       False         True
# 8361-LTMKD          False         True       False         True
# 3186-AJIEK          False         True        True        False
#
#             Dependents_No  ...  StreamingTV_Yes  StreamingMovies_No  \
# customerID                 ...
# 7590-VHVEG           True  ...            False                True
# 5575-GNVDE           True  ...            False                True
# 3668-QPYBK           True  ...            False                True
# 7795-CFOCW           True  ...            False                True
# 9237-HQITU           True  ...            False                True
# ...                   ...  ...              ...                 ...
# 6840-RESVB          False  ...             True               False
# 2234-XADUH          False  ...             True               False
# 4801-JZAZL          False  ...            False                True
# 8361-LTMKD           True  ...            False                True
# 3186-AJIEK           True  ...             True               False
#
#             StreamingMovies_No internet service  StreamingMovies_Yes  \
# customerID
# 7590-VHVEG                                False                False
# 5575-GNVDE                                False                False
# 3668-QPYBK                                False                False
# 7795-CFOCW                                False                False
# 9237-HQITU                                False                False
# ...                                         ...                  ...
# 6840-RESVB                                False                 True
# 2234-XADUH                                False                 True
# 4801-JZAZL                                False                False
# 8361-LTMKD                                False                False
# 3186-AJIEK                                False                 True
#
#             PaperlessBilling_No  PaperlessBilling_Yes  \
# customerID
# 7590-VHVEG                False                  True
# 5575-GNVDE                 True                 False
# 3668-QPYBK                False                  True
# 7795-CFOCW                 True                 False
# 9237-HQITU                False                  True
# ...                         ...                   ...
# 6840-RESVB                False                  True
# 2234-XADUH                False                  True
# 4801-JZAZL                False                  True
# 8361-LTMKD                False                  True
# 3186-AJIEK                False                  True
#
#             PaymentMethod_Bank transfer (automatic)  \
# customerID
# 7590-VHVEG                                    False
# 5575-GNVDE                                    False
# 3668-QPYBK                                    False
# 7795-CFOCW                                     True
# 9237-HQITU                                    False
# ...                                             ...
# 6840-RESVB                                    False
# 2234-XADUH                                    False
# 4801-JZAZL                                    False
# 8361-LTMKD                                    False
# 3186-AJIEK                                     True
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 7590-VHVEG                                  False
# 5575-GNVDE                                  False
# 3668-QPYBK                                  False
# 7795-CFOCW                                  False
# 9237-HQITU                                  False
# ...                                           ...
# 6840-RESVB                                  False
# 2234-XADUH                                   True
# 4801-JZAZL                                  False
# 8361-LTMKD                                  False
# 3186-AJIEK                                  False
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check
# customerID
# 7590-VHVEG                            True                       False
# 5575-GNVDE                           False                        True
# 3668-QPYBK                           False                        True
# 7795-CFOCW                           False                       False
# 9237-HQITU                            True                       False
# ...                                    ...                         ...
# 6840-RESVB                           False                        True
# 2234-XADUH                           False                       False
# 4801-JZAZL                            True                       False
# 8361-LTMKD                           False                        True
# 3186-AJIEK                           False                       False
#
# [7021 rows x 43 columns]

# %%
# Fit and transform the data
df_churn = pd.DataFrame(scaler.fit_transform(df_churn), columns=df_churn.columns)

df_churn
# Out:
#       Churn
# 0       0.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       1.0
# ...     ...
# 7016    0.0
# 7017    0.0
# 7018    0.0
# 7019    1.0
# 7020    0.0
#
# [7021 rows x 1 columns]

# %%
df_encoded.to_csv('data_no_Churn(Yusuf Muhammed Bedir).csv', index=True)

# %%
df_churn.to_csv('Churn(Yusuf Muhammed Bedir).csv', index=True)

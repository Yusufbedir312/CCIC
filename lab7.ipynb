# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
data= pd.read_csv("movies.csv")

# %%
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
data.interpolate(inplace=True)
# Out:
# C:\Users\bedir\AppData\Local\Temp\ipykernel_13036\3565517206.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data.interpolate(inplace=True)

# %%
data.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# x= Rating & votes   Y= Revenue (Millions)
# split  x_train y_train  x_test y_test     80 --> train 20-> test  or 70--> train 30-> test

# %%
y=data["Revenue (Millions)"]
y
# Out:
# 0      333.130
# 1      126.460
# 2      138.120
# 3      270.320
# 4      325.020
#         ...
# 995     36.130
# 996     17.540
# 997     58.010
# 998     38.825
# 999     19.640
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
x_train=data.loc[:700,["Rating","Votes"]]
x_test=data.loc[701:,["Rating","Votes"]]

# %%
y_train=data.loc[:700,["Revenue (Millions)"]]
y_test=data.loc[701:,["Revenue (Millions)"]]

# %%
y_test
# Out:
#      Revenue (Millions)
# 701             218.630
# 702              90.360
# 703              49.550
# 704              23.230
# 705              42.840
# ..                  ...
# 995              36.130
# 996              17.540
# 997              58.010
# 998              38.825
# 999              19.640
#
# [299 rows x 1 columns]

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#4) test model  y=a+bx
y_predict=model.predict(x_test) # y_test

# %%
y_predict
# Out:
# array([[195.01229645],
#        [107.21161072],
#        [ 66.16121576],
#        [ 60.21697738],
#        [ 45.73636416],
#        [ 92.68050837],
#        [ 32.86844546],
#        [ 65.28314823],
#        [ 42.95665706],
#        [158.17985849],
#        [ 13.96800184],
#        [ 33.3188255 ],
#        [ 31.16895908],
#        [ 70.28613133],
#        [ 80.35719762],
#        [ 51.56760649],
#        [ 70.44600514],
#        [117.70570449],
#        [115.73986382],
#        [ 50.11636358],
#        [ 52.97140922],
#        [107.13067021],
#        [ 66.50122414],
#        [ 81.42509926],
#        [109.98970677],
#        [129.52075503],
#        [118.7731386 ],
#        [102.05059276],
#        [ 51.95821065],
#        [ 92.9991741 ],
#        [ 92.14487411],
#        [ 23.45071449],
#        [147.68884692],
#        [ 13.71562755],
#        [102.84710746],
#        [ 49.31834933],
#        [ 83.43545444],
#        [ 52.08702563],
#        [ 99.18262061],
#        [ 62.06075828],
# ...

# %%
print(model.coef_) #y= w0 + w1*x1 +w2*x2
# Out:
# [[-1.89616574e+01  3.51162454e-04]]

# %%
print(model.intercept_)
# Out:
# [154.04455077]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
dt=sns.load_dataset("tips")

# %%
dt  # y--> total_bill  x--> tip & size
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
